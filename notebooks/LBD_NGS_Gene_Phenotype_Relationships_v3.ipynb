# %% [markdown]
# # LBD for NGS - How many nodes are needed to connect the gene with the phenotype

# %% [raw]
# ### PX4957
# PX4957	HP:0001300	Parkinsonism	C0242422	0
# PX4957	HP:0002071	Abnormality of extrapyramidal motor function	C0015371	1
# PX4957	HP:0100543	Cognitive impairment	C0278061	0
# PX4957	HP:0001332	Dystonia	C0013421	1
# PX4957	HP:0100022	Abnormality of movement	C0026650	2

# %%
# Libraries
import pandas as pd
from py2neo import Graph

from datetime import datetime

# Accessing PubMed
from Bio import Entrez

# %%
# Connect to the Neo4J database
# graph = Graph("bolt://212.235.239.171:7687", 
#               user='neo4j', 
#               password='semMedDb2020', 
#               name='semmed43')

# graph = Graph("bolt://212.235.239.171:7687", 
#               user='neo4j', 
#               password='semMedDb2020', 
#               name='semmed4321')

graph = Graph("bolt://localhost:7687", 
              user='neo4j', 
              password='semmed40', 
              name='semmed40')

# %% [markdown]
# ## Load variants table

# %%
# Load gene table

variants_df = pd.read_csv('Test_Data/VARIANTS.tsv', sep='\t')

# %% [markdown]
# ---

# %% [markdown]
# ## Example 1: PX4957

# %% [raw]
# ### PX4957
# PX4957	HP:0001300	Parkinsonism	C0242422	0
# PX4957	HP:0002071	Abnormality of extrapyramidal motor function	C0015371	1
# PX4957	HP:0100543	Cognitive impairment	C0278061	0
# PX4957	HP:0001332	Dystonia	C0013421	1
# PX4957	HP:0100022	Abnormality of movement	C0026650	2
#
# Genes
# NR4A2
# Nuclear Receptor Subfamily 4, Group A, Member 2
# C2720177
#
# PKD1L3 protein, human
# C2934671

# %%
# Select candidate genes for patient

patient = 'PX4957'
candidate_genes = variants_df.loc[variants_df['PatientID'] == patient]['GeneName'].to_list()

# %%
# Loop queries

results = {}

for gene_name in candidate_genes:
    print(gene_name)

    query = f"\
    MATCH (x:Concept), (y:Concept) \
    WHERE (x.name =~ '(?i).*{gene_name}.*') AND \
    (y:sosy) AND y.cui in ['C0242422', 'C0015371', 'C0278061', 'C0013421', 'C0026650'] \
    MATCH p = allShortestPaths((x)-[:CAUSES|AFFECTS*..6]-(y)) \
    WHERE all(n in nodes(p)[1..-1] WHERE n:gngm OR n:aapp OR n:dsyn OR n:patf) \
    RETURN \
    count(p) as count, length(p) as length \
    LIMIT 100"
    
    out = graph.run(query).to_data_frame()
    if len(out) > 0:
        out_series = out.iloc[0]
    else:
        out_series = pd.Series({'count': 0, 'length': 0})
    out_series.name = gene_name
    
    results[gene_name] = out_series
# Out:
# ABCA7
# ABCC3
# ABCC8
# ADAMTS20
# AKAP11
# ALPP
# ANKRD36C
# ANKRD36C
# AQP9
# ARAP1
# ARHGEF1
# ASB18
# ATN1
# ATN1
# ATP2A3
# ATXN2
# AZI2
# B3GAT2
# BMP10
# BOP1
# C2CD4D
# CBL
# CCDC88C
# CDC20
# CFHR3
# COL26A1
# CPT1A
# CREBBP
# CSF1R
# CUBN
# CYP11B1
# CYP26A1
# CYP2R1
# CYP4F11
# DBF4
# DCP1B
# DDN
# DDX53
# DNAH17
# DYSF
# EAF1
# EFS
# EPB41L2
# FANCA
# FBN1
# FBXO17
# FEM1C
# FGD5
# FMR1NB
# FRMPD1
# GPS1
# GRIK4
# GYS2
# HTT
# HTT
# IFRD2
# INTS1
# KCNN3
# KCNN3
# KCP
# KIAA1841
# KIF27
# KIRREL3
# LARP4B
# LRTM2
# MAML1
# MAN1C1
# MAP3K14
# MB21D2
# MED14
# MPHOSPH8
# MSLN
# MUC19
# NPC1
# NR2C1
# NR4A2
# NTN5
# NUDCD3
# NUTM2A
# NYNRIN
# PAPSS2
# PAX9
# PCOLCE2
# PDE10A
# PHACTR3
# PICK1
# PKD1
# PKD1
# PKD1L3
# PKD2L1
# PMPCA
# PNKP
# POTED
# PTCH2
# PTPN7
# RECQL4
# RFPL4B
# RHOXF2B
# SACS
# SCRIB
# SEC31A
# SEC31A
# SECISBP2L
# SEMA3B
# SENP5
# SGK1
# SGO1
# SH2D2A
# SIGLEC1
# SMARCC2
# SPG11
# SPINT1
# STARD10
# STAU2
# SUN2
# SYNE4
# SYTL4
# TAF1
# TEX11
# TNF
# TPSAB1
# TTN
# TTN
# UMAD1
# VPS13C
# VWDE
# WSCD2
# ZBBX
# ZC3H12D
# ZNF517
# ZNF614
# ZNF682

# %%
results_df = pd.DataFrame(results).T

# %%
results_df.loc[results_df['count'] > 0].sort_values(by=['length', 'count'], ascending=(True, False))
# Out:
#           count  length
# DYSF        304       2
# TNF         153       2
# NR4A2         7       2
# HTT           5       2
# ATXN2         4       2
# SGK1          4       2
# RECQL4        3       2
# VPS13C        3       2
# ABCA7         2       2
# AQP9          2       2
# CSF1R         2       2
# NR2C1         2       2
# SUN2          2       2
# CFHR3         1       2
# PICK1         1       2
# ZC3H12D       1       2
# CPT1A       472       3
# SIGLEC1     409       3
# GPS1        392       3
# ALPP        368       3
# SENP5       298       3
# NPC1        292       3
# CYP11B1     285       3
# ARAP1       266       3
# CYP26A1     251       3
# COL26A1     223       3
# CREBBP      218       3
# FBN1        213       3
# KCNN3       208       3
# ARHGEF1     206       3
# TAF1        203       3
# CBL         183       3
# ATN1        153       3
# PDE10A      146       3
# SPG11       128       3
# PKD2L1      108       3
# SEMA3B      106       3
# MSLN        103       3
# SACS         98       3
# TTN          86       3
# SCRIB        83       3
# PTCH2        76       3
# SGO1         76       3
# EAF1         63       3
# PMPCA        61       3
# MAP3K14      58       3
# FGD5         55       3
# PAPSS2       39       3
# EFS          38       3
# CUBN         36       3
# CYP2R1       32       3
# CCDC88C      25       3
# PKD1         23       3
# EPB41L2      17       3
# ABCC3        16       3
# FANCA        16       3
# TPSAB1        2       3
# ADAMTS20      1       3

# %% [markdown]
# ## Example 2: PX8847

# %% [raw]
# ### PX8847
#
# Correct target gene:
# NEMF ??

# %%
# Select candidate genes for patient

patient = 'PX8847'
candidate_genes = variants_df.loc[variants_df['PatientID'] == patient]['GeneName'].to_list()

# %%
len(candidate_genes)
# Out:
# 107

# %%
variants_df.loc[variants_df['PatientID'] == patient].iloc[51:100]
# Out:
#      GeneName PatientID                               VariantPosition  \
# 256     LAMA3    PX8847                             chr18:21492774C>T
# 260      LDHA    PX8847                             chr11:18427109C>T
# 262     LIN7A    PX8847                             chr12:81283065C>G
# 265       LPA    PX8847                             chr6:161056313C>T
# 267   LRRC75B    PX8847                             chr22:24982098G>A
# 268    LRSAM1    PX8847                           chr9:130243534ATT>A
# 276    MAP2K2    PX8847                              chr19:4097323C>T
# 278   MAP3K21    PX8847                             chr1:233463913T>A
# 279     MATR3    PX8847                             chr5:138653129G>T
# 281    MBTPS1    PX8847                             chr16:84094333C>A
# 284    MICAL2    PX8847                             chr11:12278477C>G
# 287  MIR1268A    PX8847                             chr9:131329570G>A
# 292      MKS1    PX8847                             chr17:56292170G>A
# 297     MSTO1    PX8847                            chr1:155581048AG>A
# 298    MTMR14    PX8847                               chr3:9719274C>G
# 299    MTMR14    PX8847                               chr3:9724719T>G
# 321    NDUFV3    PX8847                             chr21:44317037A>T
# 341     OBSCN    PX8847                             chr1:228547542G>A
# 342    OLFML3    PX8847                             chr1:114523105G>A
# 346      ORC3    PX8847                              chr6:88299904G>A
# 347     PACS1    PX8847                             chr11:65838034C>T
# 363   PHACTR3    PX8847                             chr20:58348487C>T
# 368   PIP5KL1    PX8847                             chr9:130690054G>C
# 386      PSPH    PX8847                              chr7:56088794A>T
# 399   RPS6KB2    PX8847                             chr11:67201494T>C
# 404      SBSN    PX8847                             chr19:36018493C>T
# 405    SCN10A    PX8847                              chr3:38752198C>T
# 408      SDHA    PX8847                                chr5:216716T>C
# 415      SETX    PX8847                             chr9:135163743T>C
# 426   SLC2A13    PX8847                             chr12:40345125C>T
# 429   SLC38A4    PX8847                             chr12:47172402C>T
# 435   SNORD68    PX8847                             chr16:89627541A>T
# 436    SOWAHC    PX8847                             chr2:110372899G>A
# 439     SPAG9    PX8847                             chr17:49067155G>A
# 441      SPG7    PX8847                             chr16:89599147C>T
# 443    SPTBN5    PX8847                             chr15:42179409A>C
# 455    TAS1R3    PX8847                               chr1:1267263C>T
# 460      TCHH    PX8847                             chr1:152080928G>A
# 461      TDP1    PX8847                            chr14:90458397G>GT
# 464      TFF2    PX8847                             chr21:43767683G>C
# 468   TMEM107    PX8847                              chr17:8076912C>T
# 470    TMEM43    PX8847                              chr3:14177699C>T
# 472   TMEM87B    PX8847                            chr2:112839023A>AT
# 474      TPK1    PX8847                             chr7:144304165T>A
# 482     TRRAP    PX8847                              chr7:98574334A>G
# 483     TRUB1    PX8847                            chr10:116698300T>A
# 487    TTC39C    PX8847                             chr18:21712494A>G
# 494      UBR4    PX8847                              chr1:19486775C>A
# 500    VPS13B    PX8847  chr8:100844596G>GTTTTTTTTTTTTTTTTTTTTTTTTTTT
#
#     FunctionalImpact  CADDscore  Entrez.Gene.ID  Ensembl.Gene.ID  HTZinSLO  \
# 256         MODERATE  28.000000            3909  ENSG00000053747         1
# 260         MODERATE  27.700001            3939  ENSG00000134333         2
# 262         MODERATE  26.200001            8825  ENSG00000111052         1
# 265         MODERATE  22.500000            4018  ENSG00000198670         1
# 267         MODERATE  21.700001          388886  ENSG00000178026         3
# 268         MODIFIER  -1.000000           90678  ENSG00000148356         0
# 276         MODERATE  24.600000            5605  ENSG00000126934         2
# 278         MODERATE  24.900000           84451  ENSG00000143674         1
# 279         MODIFIER  -1.000000            9782  ENSG00000015479         2
# 281         MODERATE  22.200001            8720  ENSG00000140943         2
# 284         MODERATE  15.300000            9645  ENSG00000133816         2
# 287         MODIFIER  -1.000000       100302233  ENSG00000221641         1
# 292              LOW  -1.000000           54903  ENSG00000011143         1
# 297             HIGH  -1.000000           55154  ENSG00000125459         1
# 298         MODIFIER  -1.000000           64419  ENSG00000163719         1
# 299         MODIFIER  -1.000000           64419  ENSG00000163719         4
# 321         MODERATE  13.670000            4731  ENSG00000160194         2
# 341         MODERATE   0.382000           84033  ENSG00000154358         1
# 342         MODERATE  26.400000           56944  ENSG00000116774         1
# 346         MODERATE  21.200001           23595  ENSG00000135336         2
# 347         MODERATE  22.000000           55690  ENSG00000175115         2
# 363         MODERATE  28.799999          116154  ENSG00000087495         1
# 368              LOW  -1.000000          138429  ENSG00000167103         1
# 386         MODERATE  22.000000            5723  ENSG00000146733         2
# 399         MODERATE  23.900000            6199  ENSG00000175634         1
# 404         MODERATE   5.513000          374897  ENSG00000189001         1
# 405         MODIFIER  -1.000000            6336  ENSG00000185313         2
# 408         MODIFIER  -1.000000            6389  ENSG00000073578         4
# 415              LOW  -1.000000           23064  ENSG00000107290         2
# 426         MODERATE  26.200001          114134  ENSG00000151229         3
# 429         MODERATE  16.059999           55089  ENSG00000139209         1
# 435         MODIFIER  -1.000000          606500  ENSG00000200084         1
# 436         MODERATE  26.900000           65124  ENSG00000198142         1
# 439         MODERATE  22.299999            9043  ENSG00000008294         1
# 441         MODIFIER  -1.000000            6687  ENSG00000197912         2
# 443             HIGH  24.900000           51332  ENSG00000137877         1
# 455         MODERATE  20.299999           83756  ENSG00000169962         1
# 460         MODERATE  19.719999            7062  ENSG00000159450         3
# 461         MODIFIER  -1.000000           55775  ENSG00000042088         0
# 464         MODERATE  21.799999            7032  ENSG00000160181         1
# 468         MODIFIER  -1.000000           84314  ENSG00000179029         4
# 470         MODIFIER  -1.000000           79188  ENSG00000170876         1
# 472             HIGH  -1.000000           84910  ENSG00000153214         1
# 474         MODIFIER  -1.000000           27010  ENSG00000196511         4
# 482         MODERATE  20.600000            8295  ENSG00000196367         2
# 483             HIGH  27.500000          142940  ENSG00000165832         1
# 487         MODERATE  22.799999          125488  ENSG00000168234         1
# 494         MODERATE  22.200001           23352  ENSG00000127481         1
# 500         MODERATE  -1.000000          157680  ENSG00000132549         2
#
#      HMZinSLO  GnomADAlleleCount  GnomADHMZ         SIFT          PolyPhen2  \
# 256         0                  0          0  Deleterious                NaN
# 260         0                  1          0  Deleterious  Possibly damaging
# 262         0                  0          0  Deleterious  Probably damaging
# 265         0                  0          0  Deleterious                NaN
# 267         0                  5          0  Deleterious             Benign
# 268         0                 11          0          NaN                NaN
# 276         0                  2          0    Tolerated  Probably damaging
# 278         0                  0          0  Deleterious  Probably damaging
# 279         0                  1          0          NaN                NaN
# 281         0                  0          0    Tolerated             Benign
# 284         0                  1          0    Tolerated             Benign
# 287         0                  0          0          NaN                NaN
# 292         0                  0          0          NaN                NaN
# 297         0                  0          0          NaN                NaN
# 298         0                  0          0          NaN                NaN
# 299         0                  0          0          NaN                NaN
# 321         0                  0          0  Deleterious             Benign
# 341         0                  0          0    Tolerated             Benign
# 342         0                  2          0  Deleterious  Probably damaging
# 346         0                  1          0    Tolerated             Benign
# 347         0                  2          0  Deleterious             Benign
# 363         0                  0          0  Deleterious  Probably damaging
# 368         0                  0          0          NaN                NaN
# 386         0                  0          0  Deleterious             Benign
# 399         0                  1          0  Deleterious  Possibly damaging
# 404         0                  0          0  Deleterious                NaN
# 405         0                  2          0          NaN                NaN
# 408         0                 13          0          NaN                NaN
# 415         0                  0          0          NaN                NaN
# 426         0                  0          0  Deleterious  Probably damaging
# 429         0                  0          0    Tolerated             Benign
# 435         0                  0          0          NaN                NaN
# 436         0                  0          0  Deleterious  Probably damaging
# 439         0                  1          0    Tolerated  Probably damaging
# 441         0                  2          0          NaN                NaN
# 443         0                  0          0          NaN                NaN
# 455         0                  2          0  Deleterious  Possibly damaging
# 460         0                  0          0  Deleterious  Probably damaging
# 461         0                 30          0          NaN                NaN
# 464         0                  2          0  Deleterious  Probably damaging
# 468         0                 18          0          NaN                NaN
# 470         0                  1          0          NaN                NaN
# 472         0                  0          0          NaN                NaN
# 474         0                 13          0          NaN                NaN
# 482         0                  0          0    Tolerated             Benign
# 483         0                  0          0          NaN                NaN
# 487         0                  0          0    Tolerated             Benign
# 494         0                  0          0    Tolerated             Benign
# 500         0                  0          0          NaN                NaN
#
#       MutationTaster            ClinVar  SIFT_modified  PolyPhen2_modified  \
# 256  Disease causing                NaN           -1.0                 NaN
# 260  Disease causing                NaN           -1.0                -1.0
# 262  Disease causing                NaN           -1.0                -1.0
# 265           Benign                NaN           -1.0                 NaN
# 267           Benign                NaN           -1.0                -1.0
# 268              NaN                NaN            NaN                 NaN
# 276  Disease causing                VUS           -1.0                -1.0
# 278  Disease causing                NaN           -1.0                -1.0
# 279              NaN                NaN            NaN                 NaN
# 281  Disease causing                NaN           -1.0                -1.0
# 284           Benign                NaN           -1.0                -1.0
# 287              NaN                NaN            NaN                 NaN
# 292              NaN                VUS            NaN                 NaN
# 297              NaN                NaN            NaN                 NaN
# 298              NaN                NaN            NaN                 NaN
# 299              NaN                NaN            NaN                 NaN
# 321  Disease causing                NaN           -1.0                -1.0
# 341           Benign                NaN           -1.0                -1.0
# 342  Disease causing                NaN           -1.0                -1.0
# 346  Disease causing                NaN           -1.0                -1.0
# 347           Benign                NaN           -1.0                -1.0
# 363  Disease causing                NaN           -1.0                -1.0
# 368              NaN                NaN            NaN                 NaN
# 386  Disease causing                NaN           -1.0                -1.0
# 399  Disease causing                NaN           -1.0                -1.0
# 404           Benign                NaN           -1.0                 NaN
# 405              NaN                NaN            NaN                 NaN
# 408              NaN                NaN            NaN                 NaN
# 415              NaN                NaN            NaN                 NaN
# 426  Disease causing                NaN           -1.0                -1.0
# 429           Benign                NaN           -1.0                -1.0
# 435              NaN                NaN            NaN                 NaN
# 436  Disease causing                NaN           -1.0                -1.0
# 439  Disease causing                NaN           -1.0                -1.0
# 441              NaN                NaN            NaN                 NaN
# 443  Disease causing                NaN            NaN                 NaN
# 455           Benign                NaN           -1.0                -1.0
# 460           Benign                NaN           -1.0                -1.0
# 461              NaN                NaN            NaN                 NaN
# 464  Disease causing                NaN           -1.0                -1.0
# 468              NaN  Likely pathogenic            NaN                 NaN
# 470              NaN                NaN            NaN                 NaN
# 472              NaN                NaN            NaN                 NaN
# 474              NaN                NaN            NaN                 NaN
# 482  Disease causing                NaN           -1.0                -1.0
# 483  Disease causing                NaN            NaN                 NaN
# 487  Disease causing                NaN           -1.0                -1.0
# 494  Disease causing                NaN           -1.0                -1.0
# 500              NaN                NaN            NaN                 NaN
#
#      MutationTaster_modified
# 256                     -1.0
# 260                     -1.0
# 262                     -1.0
# 265                     -1.0
# 267                     -1.0
# 268                      NaN
# 276                     -1.0
# 278                     -1.0
# 279                      NaN
# 281                     -1.0
# 284                     -1.0
# 287                      NaN
# 292                      NaN
# 297                      NaN
# 298                      NaN
# 299                      NaN
# 321                     -1.0
# 341                     -1.0
# 342                     -1.0
# 346                     -1.0
# 347                     -1.0
# 363                     -1.0
# 368                      NaN
# 386                     -1.0
# 399                     -1.0
# 404                     -1.0
# 405                      NaN
# 408                      NaN
# 415                      NaN
# 426                     -1.0
# 429                     -1.0
# 435                      NaN
# 436                     -1.0
# 439                     -1.0
# 441                      NaN
# 443                     -1.0
# 455                     -1.0
# 460                     -1.0
# 461                      NaN
# 464                     -1.0
# 468                      NaN
# 470                      NaN
# 472                      NaN
# 474                      NaN
# 482                     -1.0
# 483                     -1.0
# 487                     -1.0
# 494                     -1.0
# 500                      NaN

# %%
# List of symptoms CUI

symptoms_cui = [
    'C0343146', 
    'C0221369', 
    'C0231679', 
    'C0241521', 
    'C0410740', 
    'C2674737', 
    'C0685409', 
    'C0009917', 
    'C0239830', 
    'C0018564', 
    'C1836019', 
    'C0009081', 
    'C0016506', 
    'C1096086', 
    'C0231678', 
    'C1406835', 
    'C0221369', 
    'C2674738', 
]

symptoms_cui_query_string = "','".join(symptoms_cui)

# %%
# Loop queries

results = {}

for gene_name in candidate_genes:
    print(gene_name)

    query = f"\
    MATCH (x:Concept), (y:Concept) \
    WHERE (x.name =~ '(?i).*{gene_name}.*') AND \
    y.cui in ['C0343146','C0221369', 'C0231679', 'C0241521','C0410740', 'C2674737', \
    'C0685409', 'C0009917', 'C0239830', 'C0018564', 'C1836019', 'C0009081', 'C0016506', 'C1096086', 'C0231678', \
    'C1406835', 'C0221369', 'C2674738'] \
    MATCH p = allShortestPaths((x)-[:CAUSES|AFFECTS|STIMULATES|INHIBITS|AUGMENTS|ASSOCIATED_WITH*..6]-(y)) \
    WHERE all(n in nodes(p)[1..-1] WHERE n:gngm OR n:aapp OR n:dsyn OR n:patf) \
    RETURN \
    count(p) as count, length(p) as length \
    LIMIT 100"
    
    out = graph.run(query).to_data_frame()
    if len(out) > 0:
        out_series = out.iloc[0]
    else:
        out_series = pd.Series({'count': 0, 'length': 0})
    out_series.name = gene_name
    
    results[gene_name] = out_series
# Out:
# AAMDC
# ACCS
# ADAMTS12
# ADAMTS18
# ADGRV1
# AKAP3
# ANKRD11
# ANKRD36B
# ANKRD36C
# ANKRD36C
# APOBEC3F
# ARHGAP31
# ARHGEF37
# ARID1A
# ARRB2
# ATXN3
# ATXN3
# C2
# CAPN12
# CATSPERG
# CCDC36
# CDHR4
# CEACAM7
# CELSR1
# CHML
# COA5
# COL6A6
# DAG1
# DLC1
# DNAH5
# DNAJA3
# DNAJB3
# DYNC1H1
# EFHC1
# EMID1
# ENTHD1
# FAM81A
# FBRS
# FLVCR1
# GABRP
# GDPD3
# GRIN2A
# HCAR1
# HRNR
# IGFBP7
# INSRR
# ITGB2
# KCNN3
# KDR
# KEAP1
# KIR2DS4
# LAMA3
# LDHA
# LIN7A
# LPA
# LRRC75B
# LRSAM1
# MAP2K2
# MAP3K21
# MATR3
# MBTPS1
# MICAL2
# MIR1268A
# MKS1
# MSTO1
# MTMR14
# MTMR14
# NDUFV3
# OBSCN
# OLFML3
# ORC3
# PACS1
# PHACTR3
# PIP5KL1
# PSPH
# RPS6KB2
# SBSN
# SCN10A
# SDHA
# SETX
# SLC2A13
# SLC38A4
# SNORD68
# SOWAHC
# SPAG9
# SPG7
# SPTBN5
# TAS1R3
# TCHH
# TDP1
# TFF2
# TMEM107
# TMEM43
# TMEM87B
# TPK1
# TRRAP
# TRUB1
# TTC39C
# UBR4
# VPS13B
# ZFP57
# ZGRF1
# ZNF200
# ZNF43
# ZNF467
# ZNF560
# ZNF714

# %%
patient_2_df = pd.DataFrame(results).T

# %%
patient_2_df.loc[patient_2_df['count'] > 0].sort_values(by=['length', 'count'], ascending=(True, False))
# Out:
#          count  length
# LPA        373       2
# FLVCR1      41       2
# FBRS        21       2
# GRIN2A      18       2
# MBTPS1      15       2
# ...        ...     ...
# ADGRV1      11       3
# CEACAM7      9       3
# GDPD3        8       3
# GABRP        2       3
# SDHA        30       4
#
# [80 rows x 2 columns]

# %% [markdown]
# ## Example 3: PX9097

# %% [raw]
# ### PX9097
#
# Correct target gene:
# TMEM63B

# %%
# Select candidate genes for patient

patient = 'PX9097'
candidate_genes = variants_df.loc[variants_df['PatientID'] == patient]['GeneName'].to_list()

# %%
candidate_genes
# Out:
# ['A2M',
#  'ABCA3',
#  'ACADM',
#  'ACBD7',
#  'ACVRL1',
#  'ADAMTSL2',
#  'ADAMTSL2',
#  'ADCY4',
#  'ADCY4',
#  'ADGRV1',
#  'ADSL',
#  'AHR',
#  'ALDH18A1',
#  'ALDH5A1',
#  'ALDH5A1',
#  'ALG9',
#  'ALG9',
#  'AMER1',
#  'ANK3',
#  'ANKH',
#  'ANKRD36C',
#  'ANKRD36C',
#  'ANOS1',
#  'ANTXR2',
#  'ARFGEF2',
#  'ARHGAP17',
#  'ARHGEF1',
#  'ARMC2',
#  'ASPM',
#  'ATM',
#  'ATP5A1',
#  'ATRX',
#  'ATXN1',
#  'ATXN7L2',
#  'BRAF',
#  'BTN2A1',
#  'BTN2A1',
#  'BUB1B',
#  'C10orf111',
#  'C14orf93',
#  'C16orf96',
#  'C16orf96',
#  'CACNA1A',
#  'CACNA1E',
#  'CADPS',
#  'CADPS',
#  'CADPS2',
#  'CBS',
#  'CCDC88B',
#  'CD93',
#  'CDK5',
#  'CDON',
#  'CELA2B',
#  'CEP164',
#  'CFAP58',
#  'CHN2',
#  'CLN5',
#  'CNKSR2',
#  'COL18A1',
#  'COL4A1',
#  'COL4A1',
#  'CPOX',
#  'CPT1A',
#  'CRIPAK',
#  'CTBP2',
#  'CUL4B',
#  'CYBA',
#  'DDX5',
#  'DEPDC5',
#  'DEPDC5',
#  'DGKH',
#  'DIAPH1',
#  'DOCK8',
#  'DPP10',
#  'DPYSL3',
#  'DSCC1',
#  'DUSP8',
#  'DZIP1L',
#  'EAF2',
#  'EBP',
#  'EFHC1',
#  'EFNB1',
#  'EGFLAM',
#  'EIF4B',
#  'ELMO3',
#  'ENTPD5',
#  'ENTPD5',
#  'ENTPD5',
#  'ENTPD5',
#  'EPHA6',
#  'ERMARD',
#  'FAM153B',
#  'FAM3C',
#  'FAM83A',
#  'FARS2',
#  'FBN3',
#  'FDXACB1',
#  'FDXACB1',
#  'FGFR2',
#  'FGFR2',
#  'FGFR3',
#  'FMN2',
#  'FMR1',
#  'FOXA2',
#  'FOXG1-AS1',
#  'FOXK1',
#  'FOXO1',
#  'FUCA1',
#  'GFM1',
#  'GINS1',
#  'GJC2',
#  'GLIS2',
#  'GLRA1',
#  'GMPPB',
#  'GNAQ',
#  'GOLGA6L6',
#  'GPHN',
#  'GPHN',
#  'GRIN2A',
#  'GTF3C6',
#  'HARS2',
#  'HCFC1',
#  'HDAC1',
#  'HEPH',
#  'HNRNPU',
#  'HNRNPU',
#  'HTATIP2',
#  'IL20RA',
#  'IMPDH2',
#  'KANSL3',
#  'KCNIP3',
#  'KCNN3',
#  'KCNN3',
#  'KCNQ2',
#  'KDM6A',
#  'KDM6A',
#  'KIAA1671',
#  'KIF1A',
#  'KIF3C',
#  'KIR2DS4',
#  'KRAS',
#  'KRT38',
#  'LAMB1',
#  'LAMB1',
#  'LIAS',
#  'LMBRD1',
#  'LMO7',
#  'LRFN2',
#  'LTBP1',
#  'MAN1B1',
#  'MAN2A2',
#  'MANBA',
#  'MCM7',
#  'MID2',
#  'MIP',
#  'MIR1268A',
#  'MIR320A',
#  'MIR3944',
#  'MIR6863',
#  'MMP8',
#  'MROH6',
#  'MTRR',
#  'MTTP',
#  'MUC17',
#  'MUC19',
#  'MUC19',
#  'MUC4',
#  'MUC4',
#  'MUT',
#  'MVP',
#  'MYL7',
#  'MYO18A',
#  'MYO1D',
#  'MYO7A',
#  'MYO9B',
#  'NAAA',
#  'NADK2',
#  'NDUFA10',
#  'NDUFA2',
#  'NDUFS2',
#  'NDUFS2',
#  'NEDD4L',
#  'NF1',
#  'NF1',
#  'NF1',
#  'NPC1',
#  'NPC1',
#  'NPC1',
#  'NPC1',
#  'NPC1',
#  'NPC1',
#  'NPC1',
#  'NSD1',
#  'OR10A2',
#  'OR6B2',
#  'OR8K3',
#  'PANK2',
#  'PCCA',
#  'PCCA',
#  'PCCA',
#  'PCNT',
#  'PCNT',
#  'PCNT',
#  'PEX1',
#  'PEX2',
#  'PFKL',
#  'PHF6',
#  'PIGG',
#  'PIM2',
#  'PKD1',
#  'PKD1L2',
#  'PLEKHG3',
#  'PLIN4',
#  'POLR3B',
#  'PPP1R16A',
#  'PPP3CA',
#  'PPP3CA',
#  'PRDM5',
#  'PRKAG2',
#  'PTPRO',
#  'RBFOX1',
#  'RBM33',
#  'RCE1',
#  'RNASEH2B',
#  'RNF169',
#  'RPL19',
#  'RYR3',
#  'RYR3',
#  'SAR1B',
#  'SDHA',
#  'SEMA3C',
#  'SHANK1',
#  'SLC12A5',
#  'SLC12A5',
#  'SLC20A2',
#  'SLC22A11',
#  'SLC25A13',
#  'SLC34A3',
#  'SLC35G4',
#  'SLC44A4',
#  'SLC44A4',
#  'SLC6A1',
#  'SLC9A6',
#  'SP5',
#  'SPACA1',
#  'SPTY2D1',
#  'STAMBP',
#  'SUGP2',
#  'SYNE1',
#  'SYNGAP1',
#  'TAS2R20',
#  'TBCE',
#  'TCF4',
#  'TCF4',
#  'TECPR2',
#  'TGIF2LX',
#  'THAP11',
#  'TLL1',
#  'TMEM132C',
#  'TMEM63B',
#  'TRAF7',
#  'TRAPPC9',
#  'TREML1',
#  'TREML1',
#  'TRIM65',
#  'TRMT10B',
#  'TSC1',
#  'TSEN34',
#  'TSFM',
#  'TTK',
#  'TUBGCP6',
#  'TYMP',
#  'TYRO3',
#  'UMAD1',
#  'USP17L7',
#  'VIT',
#  'VPS13B',
#  'VPS13B',
#  'XK',
#  'ZEB1',
#  'ZNF273',
#  'ZNF462',
#  'ZNF532',
#  'ZNF560',
#  'ZNF717',
#  'ZNF880',
#  'ZNF883']

# %%
# List of symptoms CUI

symptoms_cui = [
    'C0424230', 
    'C0037769', 
    'C0037769', 
    'C1836833', 
    'C0023012', 
    'C0037822', 
    'C0543888', 
    'C0085584', 
    'C0002871', 
    'C0391870', 
    'C0850715', 
    'C0560046', 
    'C0575081', 
    'C0026650'
]

symptoms_cui_query_string = "','".join(symptoms_cui)

# %%
# Loop queries

results = {}

for gene_name in candidate_genes:
    print(gene_name)

    query = f"\
    MATCH (x:Concept), (y:Concept) \
    WHERE (x.name =~ '(?i).*{gene_name}.*') AND \
    y.cui in ['C0424230', 'C0037769', 'C0037769', 'C1836833', 'C0023012', 'C0037822', 'C0543888', \
    'C0085584', 'C0002871', 'C0391870', 'C0850715', 'C0560046', 'C0575081', 'C0026650'] \
    MATCH p = allShortestPaths((x)-[:CAUSES|AFFECTS|STIMULATES|INHIBITS|AUGMENTS|ASSOCIATED_WITH*..6]-(y)) \
    WHERE all(n in nodes(p)[1..-1] WHERE n:gngm OR n:aapp OR n:dsyn OR n:patf) \
    RETURN \
    count(p) as count, length(p) as length \
    LIMIT 100"
    
    out = graph.run(query).to_data_frame()
    if len(out) > 0:
        out_series = out.iloc[0]
    else:
        out_series = pd.Series({'count': 0, 'length': 0})
    out_series.name = gene_name
    
    results[gene_name] = out_series
# Out:
# A2M
# ABCA3
# ACADM
# ACBD7
# ACVRL1
# ADAMTSL2
# ADAMTSL2
# ADCY4
# ADCY4
# ADGRV1
# ADSL
# AHR
# ALDH18A1
# ALDH5A1
# ALDH5A1
# ALG9
# ALG9
# AMER1
# ANK3
# ANKH
# ANKRD36C
# ANKRD36C
# ANOS1
# ANTXR2
# ARFGEF2
# ARHGAP17
# ARHGEF1
# ARMC2
# ASPM
# ATM
# ATP5A1
# ATRX
# ATXN1
# ATXN7L2
# BRAF
# BTN2A1
# BTN2A1
# BUB1B
# C10orf111
# C14orf93
# C16orf96
# C16orf96
# CACNA1A
# CACNA1E
# CADPS
# CADPS
# CADPS2
# CBS
# CCDC88B
# CD93
# CDK5
# CDON
# CELA2B
# CEP164
# CFAP58
# CHN2
# CLN5
# CNKSR2
# COL18A1
# COL4A1
# COL4A1
# CPOX
# CPT1A
# CRIPAK
# CTBP2
# CUL4B
# CYBA
# DDX5
# DEPDC5
# DEPDC5
# DGKH
# DIAPH1
# DOCK8
# DPP10
# DPYSL3
# DSCC1
# DUSP8
# DZIP1L
# EAF2
# EBP
# EFHC1
# EFNB1
# EGFLAM
# EIF4B
# ELMO3
# ENTPD5
# ENTPD5
# ENTPD5
# ENTPD5
# EPHA6
# ERMARD
# FAM153B
# FAM3C
# FAM83A
# FARS2
# FBN3
# FDXACB1
# FDXACB1
# FGFR2
# FGFR2
# FGFR3
# FMN2
# FMR1
# FOXA2
# FOXG1-AS1
# FOXK1
# FOXO1
# FUCA1
# GFM1
# GINS1
# GJC2
# GLIS2
# GLRA1
# GMPPB
# GNAQ
# GOLGA6L6
# GPHN
# GPHN
# GRIN2A
# GTF3C6
# HARS2
# HCFC1
# HDAC1
# HEPH
# HNRNPU
# HNRNPU
# HTATIP2
# IL20RA
# IMPDH2
# KANSL3
# KCNIP3
# KCNN3
# KCNN3
# KCNQ2
# KDM6A
# KDM6A
# KIAA1671
# KIF1A
# KIF3C
# KIR2DS4
# KRAS
# KRT38
# LAMB1
# LAMB1
# LIAS
# LMBRD1
# LMO7
# LRFN2
# LTBP1
# MAN1B1
# MAN2A2
# MANBA
# MCM7
# MID2
# MIP
# MIR1268A
# MIR320A
# MIR3944
# MIR6863
# MMP8
# MROH6
# MTRR
# MTTP
# MUC17
# MUC19
# MUC19
# MUC4
# MUC4
# MUT
# MVP
# MYL7
# MYO18A
# MYO1D
# MYO7A
# MYO9B
# NAAA
# NADK2
# NDUFA10
# NDUFA2
# NDUFS2
# NDUFS2
# NEDD4L
# NF1
# NF1
# NF1
# NPC1
# NPC1
# NPC1
# NPC1
# NPC1
# NPC1
# NPC1
# NSD1
# OR10A2
# OR6B2
# OR8K3
# PANK2
# PCCA
# PCCA
# PCCA
# PCNT
# PCNT
# PCNT
# PEX1
# PEX2
# PFKL
# PHF6
# PIGG
# PIM2
# PKD1
# PKD1L2
# PLEKHG3
# PLIN4
# POLR3B
# PPP1R16A
# PPP3CA
# PPP3CA
# PRDM5
# PRKAG2
# PTPRO
# RBFOX1
# RBM33
# RCE1
# RNASEH2B
# RNF169
# RPL19
# RYR3
# RYR3
# SAR1B
# SDHA
# SEMA3C
# SHANK1
# SLC12A5
# SLC12A5
# SLC20A2
# SLC22A11
# SLC25A13
# SLC34A3
# SLC35G4
# SLC44A4
# SLC44A4
# SLC6A1
# SLC9A6
# SP5
# SPACA1
# SPTY2D1
# STAMBP
# SUGP2
# SYNE1
# SYNGAP1
# TAS2R20
# TBCE
# TCF4
# TCF4
# TECPR2
# TGIF2LX
# THAP11
# TLL1
# TMEM132C
# TMEM63B
# TRAF7
# TRAPPC9
# TREML1
# TREML1
# TRIM65
# TRMT10B
# TSC1
# TSEN34
# TSFM
# TTK
# TUBGCP6
# TYMP
# TYRO3
# UMAD1
# USP17L7
# VIT
# VPS13B
# VPS13B
# XK
# ZEB1
# ZNF273
# ZNF462
# ZNF532
# ZNF560
# ZNF717
# ZNF880
# ZNF883

# %%
patient_3_df = pd.DataFrame(results).T

# %%
patient_3_df.loc[patient_3_df['count'] > 0].sort_values(by=['length', 'count'], ascending=(True, False)).iloc[0:50]
# Out:
#          count  length
# VIT      46215       2
# MUT       8837       2
# MIP       2866       2
# NF1        929       2
# FGFR3      550       2
# KRAS       514       2
# FOXO1      495       2
# BRAF       367       2
# GNAQ       350       2
# SLC6A1     199       2
# SLC12A5    185       2
# A2M        163       2
# LIAS       157       2
# NPC1       140       2
# GRIN2A     137       2
# TYRO3      137       2
# MUC4       127       2
# COL4A1     123       2
# FOXA2       93       2
# ANTXR2      91       2
# CACNA1A     91       2
# ANK3        82       2
# NEDD4L      82       2
# ATRX        79       2
# CPT1A       78       2
# TCF4        78       2
# DEPDC5      75       2
# CPOX        70       2
# BUB1B       65       2
# CBS         64       2
# HEPH        64       2
# KCNQ2       64       2
# NSD1        62       2
# MTRR        59       2
# KCNN3       58       2
# EFNB1       57       2
# CD93        54       2
# PPP3CA      54       2
# RBFOX1      47       2
# DPP10       45       2
# HCFC1       44       2
# CUL4B       42       2
# MMP8        40       2
# EFHC1       39       2
# PIM2        39       2
# SLC20A2     37       2
# SLC9A6      35       2
# ABCA3       31       2
# CACNA1E     31       2
# KIF1A       31       2

# %%
patient_3_df.loc['TMEM63B']
# Out:
# count     0
# length    0
# Name: TMEM63B, dtype: int64

# %% [markdown]
# ---

# %%
url_table = 'http://sembt.mf.uni-lj.si/user_guide/SemBT_semantic_types.html'

tables = pd.read_html(url_table, skiprows=1)
table_df = tables[0]
table_df.columns = ['Abbreviation', 'Semantic_type', 'Relation_count', 'Instance_count']

# %%
table_df.sort_values(by='Relation_count', ascending=False).iloc[0:30]
# Out:
#    Abbreviation                         Semantic_type  Relation_count  \
# 1          aapp       Amino Acid, Peptide, or Protein         4345793
# 4          gngm                        Gene or Genome         3422406
# 0          dsyn                   Disease or Syndrome         2603234
# 10         orch                      Organic Chemical         1550322
# 3          bpoc  Body Part, Organ, or Organ Component         1392967
# 9          phsu               Pharmacologic Substance         1100842
# 5          topp   Therapeutic or Preventive Procedure          991912
# 11         bacs         Biologically Active Substance          951043
# 7          cell                                  Cell          807092
# 6          neop                    Neoplastic Process          802419
# 13         patf                   Pathologic Function          667378
# 12         fndg                               Finding          592051
# 8          mamm                                Mammal          456140
# 23         celf                         Cell Function          370243
# 17         celc                        Cell Component          349980
# 14         popg                      Population Group          339502
# 21         orgf                     Organism Function          292346
# 16         tisu                                Tissue          291668
# 19         sosy                       Sign or Symptom          275794
# 20         diap                  Diagnostic Procedure          271705
# 28         ortf              Organ or Tissue Function          239274
# 25         medd                        Medical Device          231139
# 35         hops      Hazardous or Poisonous Substance          228022
# 29         bact                             Bacterium          206093
# 37         inch                    Inorganic Chemical          205395
# 22         inpo                   Injury or Poisoning          200300
# 2          podg             Patient or Disabled Group          199404
# 30         horm                               Hormone          196984
# 24         mobd      Mental or Behavioral Dysfunction          186453
# 31         lbpr                  Laboratory Procedure          180191
#
#     Instance_count
# 1         11503829
# 4          6946503
# 0         12591865
# 10         3485563
# 3          8711584
# 9          4226225
# 5          5108457
# 11         2922549
# 7          4346530
# 6          4650747
# 13         2828014
# 12         2906281
# 8          4230378
# 23         1004738
# 17         1606480
# 14         2419899
# 21         1307166
# 16         1634166
# 19         1400138
# 20         1385473
# 28          783507
# 25          976946
# 35          544493
# 29          740072
# 37          530002
# 22         1076107
# 2          9258258
# 30          729328
# 24          997544
# 31          695736

# %%
url_table = 'http://sembt.mf.uni-lj.si/user_guide/SemBT_relation_types_and_instances_counts.html'

tables = pd.read_html(url_table, skiprows=1)
table_df = tables[0]
table_df.columns = ['Relation_type', 'Relation_count', 'Instance_count']

# %%
table_df.sort_values(by='Relation_count', ascending=False)
# Out:
#            Relation_type  Relation_count  Instance_count
# 1            LOCATION_OF         2033678         9560753
# 5          COEXISTS_WITH         1149505         2496628
# 2                PART_OF         1132906         8736983
# 6                AFFECTS         1008068         2124063
# 3                 TREATS          993417         5435929
# 7         INTERACTS_WITH          956926         1824826
# 0             PROCESS_OF          739217        12908669
# 9        ASSOCIATED_WITH          544318         1316494
# 10                CAUSES          525082         1164132
# 12            STIMULATES          442904          845725
# 13              INHIBITS          424125          749490
# 14              AUGMENTS          384689          742944
# 4                    ISA          306793         3752806
# 15         compared_with          305476          674110
# 19              DISRUPTS          299367          533555
# 17              PRODUCES          244348          588965
# 8                   USES          225686         1391375
# 16             DIAGNOSES          205710          621281
# 11       ADMINISTERED_TO          140881         1079967
# 18             METHOD_OF          137314          584753
# 21           PREDISPOSES          111193          199806
# 22              PREVENTS           90268          195434
# 24           higher_than           84022          147335
# 25           NEG_AFFECTS           82751          103238
# 26    NEG_INTERACTS_WITH           74399           88329
# 20              PRECEDES           59940          215808
# 23             OCCURS_IN           49899          173966
# 28       NEG_LOCATION_OF           46313           61032
# 30     NEG_COEXISTS_WITH           37924           47953
# 29            NEG_TREATS           29744           49627
# 31           COMPLICATES           27262           37990
# 27        NEG_PROCESS_OF           26071           77010
# 36          NEG_INHIBITS           22691           25422
# 33      MANIFESTATION_OF           22501           30827
# 34        NEG_STIMULATES           22197           25681
# 32           CONVERTS_TO           21623           32798
# 38            NEG_CAUSES           20899           24576
# 35               same_as           19922           25558
# 40          NEG_AUGMENTS           19471           22566
# 37            lower_than           19142           25118
# 39           NEG_PART_OF           18048           23069
# 41   NEG_ASSOCIATED_WITH           17668           20790
# 43          NEG_DISRUPTS           16081           18296
# 44          NEG_PRODUCES           13754           18128
# 42   NEG_ADMINISTERED_TO            6063           18748
# 45         NEG_DIAGNOSES            5970            8134
# 46          NEG_PREVENTS            5449            6592
# 47       NEG_PREDISPOSES            4642            5069
# 48              NEG_USES            3738            5046
# 49         NEG_METHOD_OF            3536            4783
# 50         NEG_OCCURS_IN            1624            2675
# 51       NEG_higher_than            1563            1776
# 52          NEG_PRECEDES             952            1400
# 54       NEG_COMPLICATES             378             395
# 53       NEG_CONVERTS_TO             373             402
# 55  NEG_MANIFESTATION_OF             251             273
# 56        NEG_lower_than             190             195
# 57               than_as               7               7
